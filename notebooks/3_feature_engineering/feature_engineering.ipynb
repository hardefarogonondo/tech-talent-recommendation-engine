# %% [markdown]
# # I. Project Team Members

# %% [markdown]
# | Prepared by | Email | Prepared for |
# | :-: | :-: | :-: |
# | **Hardefa Rogonondo** | hardefarogonondo@gmail.com | **Tech Talent Recommendation Engine** |

# %% [markdown]
# # II. Notebook Target Definition

# %% [markdown]
# This notebook outlines the feature engineering process for the Tech Talent Recommendation Engine Project. Initially, we begin by removing identifiers and irrelevant columns from the Stack Overflow survey dataset. We then scale numerical features and apply binary relevance encoding to multi-label categorical variables, carefully treating "Null" values as placeholders. The rest categorical variables are transformed using one-hot encoding. These steps are crucial for preparing the dataset, ensuring it's primed for the subsequent phases of model training and analysis.

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
from sklearn.preprocessing import MinMaxScaler, MultiLabelBinarizer
import pandas as pd
import pickle

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## III.B. Import Data

# %%
train = pd.read_pickle('../../data/processed/train.pkl')
test = pd.read_pickle('../../data/processed/test.pkl')

# %%
train.head()
# Out:
#        ResponseId              Age                            RemoteWork  \
# 59619       59620  18-24 years old  Hybrid (some remote, some in-person)
# 67822       67823  35-44 years old                                Remote
# 15787       15788  25-34 years old                                Remote
# 13527       13528  25-34 years old  Hybrid (some remote, some in-person)
# 22192       22193  35-44 years old  Hybrid (some remote, some in-person)
#
#                                                  EdLevel  YearsCode  \
# 59619  Secondary school (e.g. American high school, G...       10.0
# 67822       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       20.0
# 15787    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       22.0
# 13527    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       11.0
# 22192     Professional degree (JD, MD, Ph.D, Ed.D, etc.)       22.0
#
#                            DevType                   Country  \
# ...

# %%
test.head()
# Out:
#        ResponseId                 Age                            RemoteWork  \
# 84079       84080     25-34 years old  Hybrid (some remote, some in-person)
# 55952       55953     25-34 years old  Hybrid (some remote, some in-person)
# 84571       84572     55-64 years old  Hybrid (some remote, some in-person)
# 61922       61923  Under 18 years old                             In-person
# 51441       51442     25-34 years old                                  Null
#
#                                                  EdLevel  YearsCode  \
# 84079       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        8.0
# 55952    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       10.0
# 84571       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       33.0
# 61922  Secondary school (e.g. American high school, G...        7.0
# 51441    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       10.0
#
#                                              DevType  \
# ...

# %% [markdown]
# # IV. Feature Engineering

# %% [markdown]
# ## IV.A. Data Shape Inspection

# %%
train.shape, test.shape
# Out:
# ((51635, 17), (22130, 17))

# %% [markdown]
# ## IV.B. Data Information Inspection

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51635 entries, 59619 to 76007
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      51635 non-null  int64
#  1   Age                             51635 non-null  object
#  2   RemoteWork                      51635 non-null  object
#  3   EdLevel                         51635 non-null  object
#  4   YearsCode                       51635 non-null  float64
#  5   DevType                         51635 non-null  object
#  6   Country                         51635 non-null  object
#  7   LanguageHaveWorkedWith          51635 non-null  object
#  8   DatabaseHaveWorkedWith          51635 non-null  object
#  9   PlatformHaveWorkedWith          51635 non-null  object
#  10  WebframeHaveWorkedWith          51635 non-null  object
#  11  MiscTechHaveWorkedWith          51635 non-null  object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22130 entries, 84079 to 88378
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      22130 non-null  int64
#  1   Age                             22130 non-null  object
#  2   RemoteWork                      22130 non-null  object
#  3   EdLevel                         22130 non-null  object
#  4   YearsCode                       22130 non-null  float64
#  5   DevType                         22130 non-null  object
#  6   Country                         22130 non-null  object
#  7   LanguageHaveWorkedWith          22130 non-null  object
#  8   DatabaseHaveWorkedWith          22130 non-null  object
#  9   PlatformHaveWorkedWith          22130 non-null  object
#  10  WebframeHaveWorkedWith          22130 non-null  object
#  11  MiscTechHaveWorkedWith          22130 non-null  object
# ...

# %% [markdown]
# ## IV.C. Identifiers Removal

# %%
def identifiers_removal(df, feature_to_remove):
    df.drop(columns=feature_to_remove, inplace=True)
    return df

# %%
feature_to_remove = ["ResponseId", "Country"]

# %%
identifiers_removal(train, feature_to_remove)
identifiers_removal(test, feature_to_remove)
train.shape, test.shape
# Out:
# ((51635, 15), (22130, 15))

# %%
train.head()
# Out:
#                    Age                            RemoteWork  \
# 59619  18-24 years old  Hybrid (some remote, some in-person)
# 67822  35-44 years old                                Remote
# 15787  25-34 years old                                Remote
# 13527  25-34 years old  Hybrid (some remote, some in-person)
# 22192  35-44 years old  Hybrid (some remote, some in-person)
#
#                                                  EdLevel  YearsCode  \
# 59619  Secondary school (e.g. American high school, G...       10.0
# 67822       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       20.0
# 15787    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       22.0
# 13527    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       11.0
# 22192     Professional degree (JD, MD, Ph.D, Ed.D, etc.)       22.0
#
#                            DevType                   LanguageHaveWorkedWith  \
# 59619        Developer, full-stack  HTML/CSS;Java;JavaScript;PHP;TypeScript
# ...

# %%
test.head()
# Out:
#                       Age                            RemoteWork  \
# 84079     25-34 years old  Hybrid (some remote, some in-person)
# 55952     25-34 years old  Hybrid (some remote, some in-person)
# 84571     55-64 years old  Hybrid (some remote, some in-person)
# 61922  Under 18 years old                             In-person
# 51441     25-34 years old                                  Null
#
#                                                  EdLevel  YearsCode  \
# 84079       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        8.0
# 55952    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       10.0
# 84571       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       33.0
# 61922  Secondary school (e.g. American high school, G...        7.0
# 51441    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       10.0
#
#                                              DevType  \
# 84079                          Developer, full-stack
# 55952  Data scientist or machine learning specialist
# ...

# %% [markdown]
# ## IV.D. Feature Scaling

# %%
def minmax_scaler(df_train, df_test, feature_to_scale):
    scaler = MinMaxScaler()
    scaler.fit(df_train[feature_to_scale])
    df_train[feature_to_scale] = scaler.transform(df_train[feature_to_scale])
    df_test[feature_to_scale] = scaler.transform(df_test[feature_to_scale])
    return df_train, df_test, scaler

# %%
feature_to_scale = ["YearsCode"]

# %%
train, test, scaler = minmax_scaler(train, test, feature_to_scale)
train.shape, test.shape
# Out:
# ((51635, 15), (22130, 15))

# %%
train.head()
# Out:
#                    Age                            RemoteWork  \
# 59619  18-24 years old  Hybrid (some remote, some in-person)
# 67822  35-44 years old                                Remote
# 15787  25-34 years old                                Remote
# 13527  25-34 years old  Hybrid (some remote, some in-person)
# 22192  35-44 years old  Hybrid (some remote, some in-person)
#
#                                                  EdLevel  YearsCode  \
# 59619  Secondary school (e.g. American high school, G...   0.196078
# 67822       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   0.392157
# 15787    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   0.431373
# 13527    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   0.215686
# 22192     Professional degree (JD, MD, Ph.D, Ed.D, etc.)   0.431373
#
#                            DevType                   LanguageHaveWorkedWith  \
# 59619        Developer, full-stack  HTML/CSS;Java;JavaScript;PHP;TypeScript
# ...

# %%
test.head()
# Out:
#                       Age                            RemoteWork  \
# 84079     25-34 years old  Hybrid (some remote, some in-person)
# 55952     25-34 years old  Hybrid (some remote, some in-person)
# 84571     55-64 years old  Hybrid (some remote, some in-person)
# 61922  Under 18 years old                             In-person
# 51441     25-34 years old                                  Null
#
#                                                  EdLevel  YearsCode  \
# 84079       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   0.156863
# 55952    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   0.196078
# 84571       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   0.647059
# 61922  Secondary school (e.g. American high school, G...   0.137255
# 51441    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   0.196078
#
#                                              DevType  \
# 84079                          Developer, full-stack
# 55952  Data scientist or machine learning specialist
# ...

# %% [markdown]
# ## IV.E. Binary Relevance & One-Hot Encoding

# %%
all_possible_values = {
    "LanguageHaveWorkedWith": ["Ada", "Apex", "APL", "Assembly", "Bash/Shell (all shells)", "C", "C#", "C++", "Clojure", "Cobol", "Crystal", "Dart", "Delphi", "Elixir", "Erlang", "F#", "Flow",
                               "Fortran", "GDScript", "Go", "Groovy", "Haskell", "HTML/CSS", "Java", "JavaScript", "Julia", "Kotlin", "Lisp", "Lua", "MATLAB", "Nim", "Objective-C", "OCaml", "Perl",
                               "PHP", "PowerShell", "Prolog", "Python", "R", "Raku", "Ruby", "Rust", "SAS", "Scala", "Solidity", "SQL", "Swift", "TypeScript", "VBA", "Visual Basic (.Net)", "Zig"],
    "DatabaseHaveWorkedWith": ["BigQuery", "Cassandra", "Clickhouse", "Cloud Firestore", "Cockroachdb", "Cosmos DB", "Couch DB", "Couchbase", "Datomic", "DuckDB", "Dynamodb", "Elasticsearch",
                               "Firebase Realtime Database", "Firebird", "H2", "IBM DB2", "InfluxDB", "MariaDB", "Microsoft Access", "Microsoft SQL Server", "MongoDB", "MySQL", "Neo4J", "Oracle",
                               "PostgreSQL", "RavenDB", "Redis", "Snowflake", "Solr", "SQLite", "Supabase", "TiDB"],
    "PlatformHaveWorkedWith": ["Amazon Web Services (AWS)", "Cloudflare", "Colocation", "Digital Ocean", "Firebase", "Fly.io", "Google Cloud", "Heroku", "Hetzner", "IBM Cloud Or Watson", "Linode",
                               "Managed Hosting", "Microsoft Azure", "Netlify", "OpenShift", "OpenStack", "Oracle Cloud Infrastructure (OCI)", "OVH", "Render", "Scaleway", "Vercel", "VMware",
                               "Vultr"],
    "WebframeHaveWorkedWith": ["Angular", "AngularJS", "ASP.NET", "ASP.NET CORE", "Blazor", "CodeIgniter", "Deno", "Django", "Drupal", "Elm", "Express", "FastAPI", "Fastify", "Flask", "Gatsby",
                               "jQuery", "Laravel", "Lit", "NestJS", "Next.js", "Node.js", "Nuxt.js", "Phoenix", "Play Framework", "Qwik", "React", "Remix", "Ruby on Rails", "Solid.js",
                               "Spring Boot", "Svelte", "Symfony", "Vue.js", "WordPress"],
    "MiscTechHaveWorkedWith": [".NET (5+)", ".NET Framework (1.0 - 4.8)", ".NET MAUI", "Apache Kafka", "Apache Spark", "Capacitor", "Cordova", "CUDA", "Electron", "Flutter", "GTK", "Hadoop",
                               "Hugging Face Transformers", "Ionic", "JAX", "Keras", "Ktor", "MFC", "Micronaut", "NumPy", "Opencv", "OpenGL", "Pandas", "Qt", "Quarkus", "RabbitMQ", "React Native",
                               "Scikit-Learn", "Spring Framework", "SwiftUI", "Tauri", "TensorFlow", "Tidyverse", "Torch/PyTorch", "Uno Platform", "Xamarin"],
    "ToolsTechHaveWorkedWith": ["Ansible", "Ant", "APT", "bandit", "Boost.Test", "build2", "Bun", "Cargo", "Catch2", "Chef", "Chocolatey", "CMake", "Composer", "cppunit", "CUTE", "Dagger",
                                "Docker", "doctest", "ELFspy", "GNU GCC", "Godot", "Google Test", "Gradle", "Homebrew", "Kubernetes", "lest", "liblittletest", "LLVM's Clang", "Make",
                                "Maven (build tool)", "Meson", "MSBuild", "MSVC", "Ninja", "Nix", "npm", "NuGet", "Pacman", "Pip", "pnpm", "Podman", "Pulumi", "Puppet", "QMake", "SCons", "snitch",
                                "Terraform", "tunit", "Unity 3D", "Unreal Engine", "Visual Studio Solution", "Vite", "Wasmer", "Webpack", "Yarn"],
    "NEWCollabToolsHaveWorkedWith": ["Android Studio", "Atom", "BBEdit", "CLion", "Code::Blocks", "condo", "DataGrip", "Eclipse", "Emacs", "Fleet", "Geany", "Goland", "Helix", "IntelliJ IDEA",
                                     "IPython", "Jupyter Notebook/JupyterLab", "Kate", "Micro", "Nano", "Neovim", "Netbeans", "Notepad++", "Nova", "PhpStorm", "PyCharm", "Qt Creator",
                                     "Rad Studio (Delphi, C++ Builder)", "Rider", "RStudio", "RubyMine", "Spyder", "Sublime Text", "TextMate", "Vim", "Visual Studio", "Visual Studio Code",
                                     "VSCodium", "WebStorm", "Xcode"],
    "OpSysPersonal use": ["AIX", "Android", "Arch", "BSD", "ChromeOS", "Cygwin", "Debian", "Fedora", "Haiku", "iOS", "iPadOS", "MacOS", "Other Linux-based", "Red Hat", "Solaris", "Ubuntu",
                          "Windows", "Windows Subsystem for Linux (WSL)"],
    "OfficeStackAsyncHaveWorkedWith": ["Adobe Workfront", "Airtable", "Asana", "Azure Devops", "Basecamp", "Cerri", "Clickup", "Confluence", "Dingtalk (Teambition)", "Document360", "Doxygen",
                                       "GitHub Discussions", "Jira", "Leankor", "Linear", "Markdown File", "Microsoft Lists", "Microsoft Planner", "Miro", "Monday.com", "Notion", "Nuclino",
                                       "Planview Projectplace Or Clarizen", "Redmine", "Redocly", "Shortcut", "Smartsheet", "Stack Overflow for Teams", "Swit", "Tettra", "Trello", "Wikis", "Wimi",
                                       "Workzone", "Wrike", "YouTrack"],
    "OfficeStackSyncHaveWorkedWith": ["Cisco Webex Teams", "Coolfire Core", "Discord", "Google Chat", "Google Meet", "IRC", "Jitsi", "Matrix", "Mattermost", "Microsoft Teams", "Ringcentral",
                                      "Rocketchat", "Signal", "Skype", "Slack", "Symphony", "Telegram", "Unify Circuit", "Whatsapp", "Wickr", "Wire", "Zoom", "Zulip"]
}

binary_relevance_columns = ["LanguageHaveWorkedWith", "DatabaseHaveWorkedWith", "PlatformHaveWorkedWith", "WebframeHaveWorkedWith", "MiscTechHaveWorkedWith", "ToolsTechHaveWorkedWith",
                            "NEWCollabToolsHaveWorkedWith", "OpSysPersonal use", "OfficeStackAsyncHaveWorkedWith", "OfficeStackSyncHaveWorkedWith"]

one_hot_encode_columns = ["Age", "RemoteWork", "EdLevel", "DevType"]

# %%
def binary_relevance_encoding(train, test, columns, all_possible_values):
    train_encoded = train.copy()
    test_encoded = test.copy()
    for column in columns:
        mlb = MultiLabelBinarizer(classes=all_possible_values[column])
        train[column] = train[column].fillna("").str.split(";")
        test[column] = test[column].fillna("").str.split(";")
        train_transformed = mlb.fit_transform(train[column])
        test_transformed = mlb.transform(test[column])
        train_new_df = pd.DataFrame(train_transformed, columns=[
                                    f"{column}_{cls}" for cls in mlb.classes_], index=train.index)
        test_new_df = pd.DataFrame(test_transformed, columns=[
                                   f"{column}_{cls}" for cls in mlb.classes_], index=test.index)
        train_encoded = pd.concat([train_encoded, train_new_df], axis=1)
        test_encoded = pd.concat([test_encoded, test_new_df], axis=1)
    train_encoded.drop(columns=columns, inplace=True)
    test_encoded.drop(columns=columns, inplace=True)
    train_encoded, test_encoded = train_encoded.align(
        test_encoded, join='left', axis=1, fill_value=0)
    return train_encoded, test_encoded, mlb


def one_hot_encoding(train, test, columns):
    train_original = train.drop(columns, axis=1)
    test_original = test.drop(columns, axis=1)
    train_encoded = pd.get_dummies(train, columns=columns, drop_first=False)
    test_encoded = pd.get_dummies(test, columns=columns, drop_first=False)
    train_encoded_only = train_encoded.drop(
        train_original.columns, axis=1).astype(int)
    test_encoded_only = test_encoded.drop(
        test_original.columns, axis=1).astype(int)
    train_final = pd.concat([train_original, train_encoded_only], axis=1)
    test_final = pd.concat([test_original, test_encoded_only], axis=1)
    train_final, test_final = train_final.align(
        test_final, join='left', axis=1, fill_value=0)
    return train_final, test_final

# %%
train_encoded, test_encoded, multi_label_binarizer = binary_relevance_encoding(
    train, test, binary_relevance_columns, all_possible_values)
train_encoded, test_encoded = one_hot_encoding(
    train_encoded, test_encoded, one_hot_encode_columns)
train_encoded.shape, test_encoded.shape
# Out:
# C:\Users\investree\.conda\envs\tech_talent\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['Null'] will be ignored
#   warnings.warn(
# C:\Users\investree\.conda\envs\tech_talent\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['Null'] will be ignored
#   warnings.warn(
# C:\Users\investree\.conda\envs\tech_talent\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['Null'] will be ignored
#   warnings.warn(
# C:\Users\investree\.conda\envs\tech_talent\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['Null'] will be ignored
#   warnings.warn(
# C:\Users\investree\.conda\envs\tech_talent\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['.NET (5+) ', 'Null'] will be ignored
#   warnings.warn(
# ...

# %%
train_encoded.head()
# Out:
#        YearsCode  LanguageHaveWorkedWith_Ada  LanguageHaveWorkedWith_Apex  \
# 59619   0.196078                           0                            0
# 67822   0.392157                           0                            0
# 15787   0.431373                           0                            0
# 13527   0.215686                           0                            0
# 22192   0.431373                           0                            0
#
#        LanguageHaveWorkedWith_APL  LanguageHaveWorkedWith_Assembly  \
# 59619                           0                                0
# 67822                           0                                0
# 15787                           0                                0
# 13527                           0                                0
# 22192                           0                                0
#
#        LanguageHaveWorkedWith_Bash/Shell (all shells)  \
# 59619                                               0
# ...

# %%
test_encoded.head()
# Out:
#        YearsCode  LanguageHaveWorkedWith_Ada  LanguageHaveWorkedWith_Apex  \
# 84079   0.156863                           0                            0
# 55952   0.196078                           0                            0
# 84571   0.647059                           0                            0
# 61922   0.137255                           0                            0
# 51441   0.196078                           0                            0
#
#        LanguageHaveWorkedWith_APL  LanguageHaveWorkedWith_Assembly  \
# 84079                           0                                0
# 55952                           0                                0
# 84571                           0                                0
# 61922                           0                                0
# 51441                           0                                0
#
#        LanguageHaveWorkedWith_Bash/Shell (all shells)  \
# 84079                                               1
# ...

# %% [markdown]
# ## IV.F. Final Feature Inspection

# %%
train_encoded.shape, test_encoded.shape
# Out:
# ((51635, 401), (22130, 401))

# %%
train_encoded.head()
# Out:
#        YearsCode  LanguageHaveWorkedWith_Ada  LanguageHaveWorkedWith_Apex  \
# 59619   0.196078                           0                            0
# 67822   0.392157                           0                            0
# 15787   0.431373                           0                            0
# 13527   0.215686                           0                            0
# 22192   0.431373                           0                            0
#
#        LanguageHaveWorkedWith_APL  LanguageHaveWorkedWith_Assembly  \
# 59619                           0                                0
# 67822                           0                                0
# 15787                           0                                0
# 13527                           0                                0
# 22192                           0                                0
#
#        LanguageHaveWorkedWith_Bash/Shell (all shells)  \
# 59619                                               0
# ...

# %%
test_encoded.head()
# Out:
#        YearsCode  LanguageHaveWorkedWith_Ada  LanguageHaveWorkedWith_Apex  \
# 84079   0.156863                           0                            0
# 55952   0.196078                           0                            0
# 84571   0.647059                           0                            0
# 61922   0.137255                           0                            0
# 51441   0.196078                           0                            0
#
#        LanguageHaveWorkedWith_APL  LanguageHaveWorkedWith_Assembly  \
# 84079                           0                                0
# 55952                           0                                0
# 84571                           0                                0
# 61922                           0                                0
# 51441                           0                                0
#
#        LanguageHaveWorkedWith_Bash/Shell (all shells)  \
# 84079                                               1
# ...

# %%
train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51635 entries, 59619 to 76007
# Columns: 401 entries, YearsCode to DevType_System administrator
# dtypes: float64(1), int32(400)
# memory usage: 79.6 MB

# %%
test_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22130 entries, 84079 to 88378
# Columns: 401 entries, YearsCode to DevType_System administrator
# dtypes: float64(1), int32(400)
# memory usage: 34.1 MB

# %% [markdown]
# ## IV.G. Export Data

# %%
with open('../../models/scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)
with open('../../models/multi_label_binarizer.pkl', 'wb') as file:
    pickle.dump(multi_label_binarizer, file)
train_encoded.to_pickle('../../data/processed/train_encoded.pkl')
test_encoded.to_pickle('../../data/processed/test_encoded.pkl')
